# %% [markdown]
# <a href="https://colab.research.google.com/github/Himkeshtak/Deep-Learning/blob/main/Embedding_based_SimpleRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install keras-preprocessing

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding,Flatten

# %%
(x_train,y_train),(y_train,y_test) = imbd.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3992947312.py in <cell line: 0>()
# ----> 1 (x_train,y_train),(y_train,y_test) = imbd.load_data()
#
# NameError: name 'imbd' is not defined

# %%
x_train = pad_sequences(x_train,padding='post',maxlen = 50)
x_test = pad_sequences(x_test,padding='post',maxlen = 50)

# %%
x_train.shape

# %%
model = Sequential()

model.add(Embedding(10000,2,50)) #10000 is the number of unique words in the vocablury
# 2 is the no.of neurons we are assigning for the processing of the all the vocablury words
# 50 is the max len of the input we are going to take for the training and testing
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5,validation_data=(x_test,y_test))
